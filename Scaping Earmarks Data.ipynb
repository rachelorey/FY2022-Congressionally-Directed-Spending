# %% [markdown]
# # Scrape Earmarks PDFs From Appropriations Site
#
# Site with all 2022 appropriations requests can be found here: https://appropriations.house.gov/transparency/fiscal-year-2022
#
# This data was collected by the Bipartisan Policy Center's Congress Project. The script was written by Rachel Orey, Senior Policy Analyst at BPC.

# %%
import ctypes
from ctypes.util import find_library
find_library("".join(("gsdll", str(ctypes.sizeof(ctypes.c_voidp) * 8), ".dll")))

import camelot
import pandas as pd

def clean(string):
    import re
    if isinstance(string, str):
        string = string.replace("\\n","")    
        string = string.replace("\\xa0","")
        string = string.replace("â€“22B"," ")
        string = string.replace("â€”"," ")
        string = string.replace("'","")
        string = string.replace("\"","")
        string = re.sub('\s+',' ',string)
        string = string.replace('$',"")
        string = string.strip()
        string = string.replace("- ","")
    return(string)

# %%
links = [["Agriculture, Rural Development, Food and Drug Administration, and Related Agencies","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/AG_CDS_002.pdf"],
    ["Commerce, Justice, Science, and Related Agencies","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/CJS_CDS_V6.pdf"],
    ["Defense","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/Defense_CDS.pdf"],
    ["Energy and Water Development, and Related Agencies","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/EW_CDSV5.pdf"],
    ["Financial Services and General Government","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/FSGG_CDS_3-4-327PM.pdf"],
    ["Homeland Security","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/HOMELAND_CDS.PDF"],
    ["Interior, Environment, and Related Agencies","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/INT_CDS_V4.PDF"],
    ["Labor, Health and Human Services, Education, and Related Agencies","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/LHHS_CDS_V3.PDF"],
    ["Military Construction, Veterans Affairs, and Related Agencies","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/MilCon_CDS.pdf"],
    ["Transportation, and Housing and Urban Development, and Related Agencies","https://appropriations.house.gov/sites/democrats.appropriations.house.gov/files/THUD_CDS_V5.PDF"]]

links = pd.DataFrame(links,columns=["Category","Link"])

# %% [markdown]
# ### Prep for Parsing Data
#
# While largely similar, some of the nine pdf tables from the approps website have different columns than the others. The below section seperates the categories according to which columns the "requestors" are in. (Other columns are just read from headers).

# %%
#seperate categories based on where the requestors columns are
five = ["Defense"]
fivesix = ["Financial Services and General Government","Interior, Environment, and Related Agencies","Military Construction, Veterans Affairs, and Related Agencies"]
threefour = ["Labor, Health and Human Services, Education, and Related Agencies"]
transp = ["Transportation, and Housing and Urban Development, and Related Agencies"]
cats = fivesix+threefour+transp

# %% [markdown]
# ### Function to Scrape Data from PDFs
#
# Depending on which category the PDF is, the scraper will collect the data and parse according to which columns are included and in which order.

# %%
def getdata(url,category):
    
    abc = camelot.read_pdf(url,pages='all')   #address of file location

    #adjust criteria based on first two columns
    if category != 'Military Construction, Veterans Affairs, and Related Agencies': #All the categories BUT military start with Agency and Account. This string is used to remove the header row from the dataset when it is included in subsequent pages. 
        columnteststrg = 'AgencyAccount'
    else:
        columnteststrg = 'AgencyState' #Military starts with Agency & State, so that string is used to remove header row

    #set index based on where the two Requestor columns are
    if category not in cats:
        indexone = 6
        indextwo = 7
    elif category in fivesix:
        indexone = 5
        indextwo = 6
    elif category in threefour:
        indexone = 3
        indextwo = 4

    if (category not in five) and (category not in transp):

        results = abc[0].df.copy()
        results.columns = results.iloc[0]
        results.columns.values[indexone] = "Requestors: House"
        results.columns.values[indextwo] = "Requestors: Senate"
        results.drop([0,1],inplace=True)

        for table in range(1,len(abc)):
            try:
                if columnteststrg in ''.join(abc[table].df.iloc[0]):
                    res = abc[table].df.copy()
                    res.columns = res.iloc[0]
                    res.columns.values[indexone] = "Requestors: House"
                    res.columns.values[indextwo] = "Requestors: Senate"
                    res.drop([0,1],inplace=True)
                    results = results.append(res)
                else:
                    res = abc[table].df.copy()
                    res.columns = results.columns.values
                    results = results.append(res)
            except:
                print(table)

    elif category in five: #just has one requestor column

        results = abc[0].df.copy()
        results.columns = results.iloc[0]
        results.drop([0],inplace=True)

        for table in range(1,len(abc)):
            if columnteststrg in ''.join(abc[table].df.iloc[0]):
                res = abc[table].df.copy()
                res.columns = res.iloc[0]
                res.drop([0],inplace=True)
                results = results.append(res)
            else:
                res = abc[table].df.copy()
                res.columns = results.columns.values
                results = results.append(res)
                
    elif category in transp: ##transp had variations within the sheet on columns, required special treatment

        for table in range(0,len(abc)):

            try: 
                if columnteststrg in ''.join(abc[table].df.iloc[0]):
                    res = abc[table].df.copy()
                    res.columns = res.iloc[0]
                    res.columns.values[6] = "Requestors: House"
                    res.columns.values[7] = "Requestors: Senate"
                    res.drop([0,1],inplace=True)
                    if table == 0:
                        results = res
                    else:
                        results = results.append(res)
                else:
                    res = abc[table].df.copy()
                    res.columns = results.columns.values
                    results = results.append(res)

            except:
                try: 
                    if columnteststrg in ''.join(abc[table].df.iloc[0]):
                        res = abc[table].df.copy()
                        res.columns = res.iloc[0]
                        res.columns.values[6] = "Requestors: House"
                        res.columns.values[7] = "Requestors: Senate"
                        res.drop([0,1],inplace=True)
                        if table == 0:
                            results = res
                        else:
                            results = results.append(res)
                    else:
                        res = abc[table].df.copy()
                        res.columns = ["Agency","Account","Project","State","Amount","Requestors: House","Requestors: Senate","Origination"]
                        results = results.append(res)
                except:
                    try:
                        if columnteststrg in ''.join(abc[table].df.iloc[0]):
                            res = abc[table].df.copy()
                            res.columns = res.iloc[0]
                            res.columns.values[6] = "Requestors: House"
                            res.columns.values[7] = "Requestors: Senate"
                            res.drop([0,1],inplace=True)
                            if table == 0:
                                results = res
                            else:
                                results = results.append(res)
                        else:
                            res = abc[table].df.copy()
                            res.columns = ["Agency","Account","Project","Recipient","State","Amount","Requestors: House","Requestors: Senate","Origination"]
                            results = results.append(res)
                    except:
                        display(table)
                        display(abc[table].df)

    results.reset_index(inplace=True,drop=True)
    
    try:
        #data cleaning
        results.columns = [clean(c) for c in results.columns]
        for c in results.columns:
            results[c] = results[c].map(lambda x: clean(x))
    
    except:
        print("failure cleaning",category)
        
    #display, return, save results
    results.to_csv("C:\\Users\\rorey\\OneDrive - Bipartisan Policy Center\\Congress\\Earmarks Data\\"+str(category)+".csv")
    display(results)
    return(results)

# %%
#for each link in the prefilled table with categories and links to pdf, scrape data with above function
for index,row in links.iterrows():
    results = getdata(row["Link"],row["Category"])
# Out:
#                                          Agency  \
# 0    Animal and Plant Health Inspection Service
# 1    Animal and Plant Health Inspection Service
# 2    Animal and Plant Health Inspection Service
# 3    Animal and Plant Health Inspection Service
# 4    Animal and Plant Health Inspection Service
# ..                                          ...
# 234      Natural Resources Conservation Service
# 235      Natural Resources Conservation Service
# 236      Natural Resources Conservation Service
# 237      Natural Resources Conservation Service
# 238      Natural Resources Conservation Service
#
#                                        Account  \
# 0                                    APHIS S&E
# 1                                    APHIS S&E
# 2                                    APHIS S&E
# 3                                    APHIS S&E
# 4                                    APHIS S&E
# ..                                         ...
# 234  Watershed and Flood Prevention Operations
# 235  Watershed and Flood Prevention Operations
# 236  Watershed and Flood Prevention Operations
# 237  Watershed and Flood Prevention Operations
# 238  Watershed and Flood Prevention Operations
#
#                                            Project  \
# 0                           Statewide Pest Surveys
# 1                           Feral Swine Management
# 2                    Invasive Species Surveillance
# 3                        Kula Agricultural Fencing
# 4                O’Hare Federal Inspection Station
# ..                                             ...
# 234                   Mississippi Flood mitigation
# 235             East Fork Irrigation Modernization
# 236  Ochoco Irrigation District Watershed Projects
# 237        Wallowa Lake Dam Rehabilitation Project
# 238          Pocasset River Flood Damage Reduction
#
#                                            Recipient Location Amount Provided  \
# 0                     Alaska Division of Agriculture       AK         100,000
# 1                 Arkansas Department of Agriculture       AR         650,000
# 2    Hawaii Department of Land and Natural Resources       HI         600,000
# 3                Maui Office of Economic Development       HI         600,000
# 4                                    City of Chicago       IL         250,000
# ..                                               ...      ...             ...
# 234                 Mississippi Watershed Operations       MS       8,400,000
# 235                    East Fork Irrigation District       OR       2,500,000
# 236                       Ochoco Irrigation District       OR       4,875,000
# 237                 Wallowa Lake Irrigation District       OR       2,000,000
# 238            City of Cranston and Town of Johnston       RI       5,000,000
#
#     Requesters: House Requesters: Senate Origination
# 0                              Murkowski           S
# 1                                Boozman           S
# 2                         Hirono; Schatz           S
# 3                                 Schatz           S
# 4                                 Durbin           S
# ..                ...                ...         ...
# 234                           Hyde-Smith           S
# 235                       Merkley; Wyden           S
# 236                       Merkley; Wyden           S
# 237                       Merkley; Wyden           S
# 238                                 Reed           S
#
# [239 rows x 9 columns]
#     Agency            Account  \
# 0      DOC  NIST—Construction
# 1      DOC  NIST—Construction
# 2      DOC  NIST—Construction
# 3      DOC  NIST—Construction
# 4      DOC  NIST—Construction
# ..     ...                ...
# 491   NASA               SSMS
# 492   NASA               SSMS
# 493   NASA               SSMS
# 494   NASA               SSMS
# 495   NASA               SSMS
#
#                                              Recipient         Location  \
# 0                            Missouri State University  Springfield, MO
# 1                                  University of Maine        Orono, ME
# 2                          Burlington Technical Center   Burlington, VT
# 3                           Fort Hays State University         Hays, KS
# 4    Kansas State University Salina Aerospace and T...       Salina, KS
# ..                                                 ...              ...
# 491                    Springfield Museums Corporation  Springfield, MA
# 492                 Atchison Amelia Earhart Foundation     Atchison, KS
# 493                 McAuliffe-Shepard Discovery Center      Concord, NH
# 494                        University of New Hampshire       Durham, NH
# 495                             Bowie State University        Bowie, MD
#
#                                                Project      Amount  \
# 0                Ozarks Health and Life Science Center  20,000,000
# 1    Green Engineering and Materials Research Facto...  10,000,000
# 2       Burlington Aviation Technology Center Facility  10,000,000
# 3                        Renovation of Forsyth Library  17,000,000
# 4    Acquisition and Renovation of Aerospace Simula...   4,750,000
# ..                                                 ...         ...
# 491                Springfield Science Museum Upgrades     750,000
# 492  Development of New Programs at the Amelia Earh...   1,000,000
# 493  McAuliffe-Shepard Discovery Center Planetarium...     348,000
# 494  University of New Hampshire Magnetometer Resea...     501,000
# 495         Hydroponics Research Laboratory Initiative   1,000,000
#
#     Requesters: House Requesters: Senate Origination
# 0                                  Blunt           S
# 1                                Collins           S
# 2                                  Leahy           S
# 3                                  Moran           S
# 4                                  Moran           S
# ..                ...                ...         ...
# 491                       Markey; Warren           S
# 492                                Moran           S
# 493                              Shaheen           S
# 494                              Shaheen           S
# 495                           Van Hollen           S
#
# [496 rows x 9 columns]
#           Agency  Account                                          Recipient  \
# 0      Air Force  RDTE,AF    Texas A&M University—Central Texas, Killeen, TX
# 1      Air Force  RDTE,AF        Central New York Defense Alliance, Rome, NY
# 2           Army   RDTE,A        Georgia Southern University, Statesboro, GA
# 3           Army   RDTE,A  Pennington Biomedical Research Center, Baton R...
# 4           Army   RDTE,A  Coalition for National Trauma Research, San An...
# 5           Army   RDTE,A  APG Centennial Celebration Association, Belcam...
# 6   Defense-Wide  RDTE,DW  Kansas City Kansas Community College, Kansas C...
# 7   Defense-Wide  RDTE,DW  National Center for Defense Manufacturing and ...
# 8   Defense-Wide  RDTE,DW                 VA Tech University, Blacksburg, VA
# 9   Defense-Wide  RDTE,DW   American Museum of Natural History, New York, NY
# 10  Defense-Wide  RDTE,DW  The University of North Carolina at Chapel Hil...
# 11  Defense-Wide  RDTE,DW  The University of Texas at San Antonio, San An...
# 12  Defense-Wide  RDTE,DW  Institute for Digital Enterprise Advancement, ...
# 13          Navy   RDTE,N          Monmouth University, West Long Branch, NJ
# 14   Space Force  RDTE,SF  The Texas A&M Engineering Experiment Station, ...
#
#                                          Project Name     Amount  \
# 0          Development of Cybersecurity Methodologies  2,990,000
# 1   Skydome: Trusted Smart-X Experimentation Envir...    200,000
# 2      Soldier Athlete Human Performance Optimization  1,500,000
# 3   Center for Excellence in Military Health and P...  3,566,666
# 4   National Trauma Research Repository Data Popul...  1,900,000
# 5                The Discovery Center at Water’s Edge    250,000
# 6           Automation Engineering Technology Program  1,981,000
# 7   El Paso Makes Contract Support for El Paso Man...    964,000
# 8          Next Generation Explosives and Propellants  1,000,000
# 9   Novel Analytical and Empirical Approaches to t...  1,500,000
# 10  Assessing and Tracking Tactical Forces Initiative  4,000,000
# 11        Cybersecurity Manufacturing Innovation Park  1,000,000
# 12  Systems Engineering Technician Education Initi...    550,000
# 13  Coastal adaptation research for improved coast...    450,000
# 14            Development of a Core Manipulator Joint  1,665,000
#
#      Requestor(s) Origination
# 0     Carter (TX)           H
# 1          Tenney           H
# 2     Carter (GA)           H
# 3     Graves (LA)           H
# 4   Ruppersberger           H
# 5   Ruppersberger           H
# 6     Davids (KS)           H
# 7         Escobar           H
# 8        Griffith           H
# 9          Nadler           H
# 10     Price (NC)           H
# 11    Castro (TX)           H
# 12       Aderholt           H
# 13        Pallone           H
# 14       Sessions           H
#                               Agency                              Account  \
# 0    Army Corps of Engineers (Civil)                         Construction
# 1    Army Corps of Engineers (Civil)                         Construction
# 2    Army Corps of Engineers (Civil)                         Construction
# 3    Army Corps of Engineers (Civil)                         Construction
# 4    Army Corps of Engineers (Civil)                         Construction
# ..                               ...                                  ...
# 242             Department of Energy  Fossil Energy and Carbon Management
# 243             Department of Energy  Fossil Energy and Carbon Management
# 244             Department of Energy  Fossil Energy and Carbon Management
# 245             Department of Energy  Fossil Energy and Carbon Management
# 246             Department of Energy  Fossil Energy and Carbon Management
#
#                                Project Name; Recipient Budget Request  \
# 0    Acequias Environmental Infrastructure, NM; U.S...
# 1    Beneficial Use of Dredged Material Pilot Progr...
# 2    Calaveras County, Section 219, CA; U.S. Army C...
# 3     Calumet Region, IN; U.S. Army Corps of Engineers
# 4    Carolina Beach and Vicinity, NC; U.S. Army Cor...
# ..                                                 ...            ...
# 242  Coal Communities Regional Innovation Cluster; ...
# 243  Coal Mine Methane Solutions; Community Office ...
# 244  Emergency Backup Generator; Melakatla Indian C...
# 245  Enhanced Outcrop Methane Capture; Southern Ute...
# 246  FEED Study for the implementation of a Carbon ...
#
#     Additional Amount Total Amount Provided Requesters: House  \
# 0           1,500,000             1,500,000
# 1           1,775,000             1,775,000
# 2           1,000,000             1,000,000
# 3          10,000,000            10,000,000             Mrvan
# 4           2,000,000             2,000,000            Rouzer
# ..                ...                   ...               ...
# 242         4,000,000             4,000,000
# 243         1,200,000             1,200,000
# 244           540,000               540,000
# 245         2,500,000             2,500,000
# 246         9,000,000             9,000,000
#
#        Requesters: Senate Origination
# 0       Heinrich; Luja´ n           S
# 1      Feinstein; Padilla           S
# 2      Feinstein; Padilla           S
# 3                                   H
# 4            Burr; Tillis         H/S
# ..                    ...         ...
# 242               Manchin           S
# 243  Bennet; Hickenlooper           S
# 244             Murkowski           S
# 245  Bennet; Hickenlooper           S
# 246               Cassidy           S
#
# [247 rows x 9 columns]
#                                            Agency  \
# 0                 General Services Administration
# 1                 General Services Administration
# 2                 General Services Administration
# 3                 General Services Administration
# 4    National Archives and Records Administration
# ..                                            ...
# 140                 Small Business Administration
# 141                 Small Business Administration
# 142                 Small Business Administration
# 143                 Small Business Administration
# 144                 Small Business Administration
#
#                                                Account  \
# 0                               Federal Buildings Fund
# 1                               Federal Buildings Fund
# 2                               Federal Buildings Fund
# 3                               Federal Buildings Fund
# 4    National Historical Publications and Records C...
# ..                                                 ...
# 140                              Salaries and Expenses
# 141                              Salaries and Expenses
# 142                              Salaries and Expenses
# 143                              Salaries and Expenses
# 144                              Salaries and Expenses
#
#                                           Project Name  \
# 0                        South State Street Properties
# 1    Santa Teresa Land Port of Entry Feasibility Study
# 2    Dennis DiConcini Land Port of Entry Feasibilit...
# 3                    Chamblee Campus Feasibility Study
# 4                         Wisconsin Historical Society
# ..                                                 ...
# 140  Atlantic City Small Business Assistance Initia...
# 141  RGV Small Business Innovation Research and Tec...
# 142  Small Business Accelerator Program in the Atla...
# 143       Black and Diverse Business Wealth Initiative
# 144       Chef Space Consumer-Packaged Goods Expansion
#
#                                              Recipient      Amount  \
# 0    Everett McKinley Dirksen United States Courtho...  52,000,000
# 1        New Mexico Border Authority, Santa Teresa, NM     500,000
# 2                      General Services Administration     500,000
# 3                      General Services Administration     500,000
# 4            Wisconsin Historical Society, Madison, WI     500,000
# ..                                                 ...         ...
# 140  Atlantic City Office of the Business Administr...     800,000
# 141  Texas A&M Engineering Experiment Station, Coll...     500,000
# 142  Urban League of Greater Atlanta, Inc., Decatur...     150,000
# 143        Louisville Metro Government, Louisville, KY     250,000
# 144  Community Ventures Corporation, Inc., Lexingto...     330,000
#
#     Requesters: House Requesters: Senate Origination
# 0                                 Durbin           S
# 1                      Heinrich, Luja´ n           S
# 2                          Kelly, Sinema           S
# 3                                Warnock           S
# 4                                Baldwin           S
# ..                ...                ...         ...
# 140          Van Drew                              H
# 141              Vela                              H
# 142     Williams (GA)                              H
# 143           Yarmuth                              H
# 144           Yarmuth                              H
#
# [145 rows x 8 columns]
#     Agency                      Account  \
# 0     FEMA  Emergency Operations Center
# 1     FEMA      Pre-Disaster Mitigation
# 2     FEMA  Emergency Operations Center
# 3     FEMA  Emergency Operations Center
# 4     FEMA  Emergency Operations Center
# ..     ...                          ...
# 117   FEMA  Emergency Operations Center
# 118   FEMA      Pre-Disaster Mitigation
# 119   FEMA  Emergency Operations Center
# 120   FEMA  Emergency Operations Center
# 121   FEMA  Emergency Operations Center
#
#                                                Project  \
# 0    Tsunami Shelter for the Alutiiq Tribe of Old H...
# 1                     Lake Lenape Dam Flood Mitigation
# 2                          Emergency Operations Center
# 3            Beaver County Emergency Operations Center
# 4            Benton County Emergency Operations Center
# ..                                                 ...
# 117       Emergency Operations Center Facility Project
# 118   WV Water Treatment Plant Auxiliary Power Project
# 119                                  Yancey County—EOC
# 120  York County emergency operations center and re...
# 121          Zapata County Emergency Operations Center
#
#                                    Recipient State     Amount  \
# 0                Alutiiq Tribe of Old Harbor        1,500,000
# 1      Atlantic County Improvement Authority    NJ  4,600,000
# 2              Baker County Sheriff’s Office    OR  2,000,000
# 3           Beaver County Emergency Services    PA    320,000
# 4                              Benton County    OR  1,000,000
# ..                                       ...   ...        ...
# 117      WV Division of Emergency Management    WV    955,000
# 118      WV Division of Emergency Management    WV    708,000
# 119                            Yancey County    NC    150,000
# 120  York County Emergency Management Agency    ME    850,000
# 121                            Zapata County    TX  1,000,000
#
#     Requesters: House Requesters: Senate Origination
# 0                              Murkowski           S
# 1            Van Drew                              H
# 2                                  Wyden           S
# 3                                  Casey           S
# 4                         Merkley, Wyden           S
# ..                ...                ...         ...
# 117                               Capito           S
# 118                               Capito           S
# 119          Cawthorn                              H
# 120                              Collins           S
# 121           Cuellar                              H
#
# [122 rows x 9 columns]
#                               Agency                        Account State  \
# 0           Bureau of Indian Affairs            Special Initiatives    AK
# 1           Bureau of Indian Affairs            Special Initiatives    AK
# 2          Bureau of Land Management               Land Acquisition    NM
# 3    Environmental Protection Agency         Science and Technology    AK
# 4    Environmental Protection Agency         Science and Technology    AK
# ..                               ...                            ...   ...
# 603            National Park Service               Land Acquisition    MO
# 604            National Park Service               Land Acquisition    NC
# 605            National Park Service  Statutory and Contractual Aid    MD
# 606            National Park Service  Statutory and Contractual Aid    WV
# 607  United States Geological Survey            Special Initiatives    AK
#
#                             Project Recipient and Name     Amount  \
# 0    Alaska Native Justice Center for Alaska Tribal...  1,000,000
# 1    Alaska Native Women’s Resource Center for Dome...    250,000
# 2               Rio Grande del Norte National Monument  3,000,000
# 3    Kodiak Area Native Association for Kodiak Regi...     50,000
# 4    University of Alaska for Alaska PFAS Remediati...  2,000,000
# ..                                                 ...        ...
# 603                         Gateway Arch National Park  2,600,000
# 604         Guilford Courthouse National Military Park    200,000
# 605  City of Annapolis for Elktonia and Carr’s Beac...  2,000,000
# 606  New River Gorge Regional Development Authority...  1,500,000
# 607  U.S. Geological Survey for Alaska Earthquake E...  1,000,000
#
#     Requesters: House Requesters: Senate Origination
# 0                              Murkowski           S
# 1                              Murkowski           S
# 2                               Heinrich           S
# 3                              Murkowski           S
# 4                              Murkowski           S
# ..                ...                ...         ...
# 603                                Blunt           S
# 604                                 Burr           S
# 605                               Cardin           S
# 606                              Manchin           S
# 607                            Murkowski           S
#
# [608 rows x 8 columns]
#                        Agency                                       Account  \
# 0         Department of Labor  Employment and Training Administration [ETA]
# 1         Department of Labor  Employment and Training Administration [ETA]
# 2         Department of Labor  Employment and Training Administration [ETA]
# 3         Department of Labor  Employment and Training Administration [ETA]
# 4         Department of Labor  Employment and Training Administration [ETA]
# ...                       ...                                           ...
# 1533  Department of Education                              Higher Education
# 1534  Department of Education                              Higher Education
# 1535  Department of Education                              Higher Education
# 1536  Department of Education                              Higher Education
# 1537  Department of Education                              Higher Education
#
#                                     Project Description    Requesters: House  \
# 0     AIDS Service Center of Lower Manhattan, Inc. d...  Maloney, Carolyn B.
# 1     American Indian OIC, MN, for job training prog...
# 2     Anne Arundel County Government, Annapolis, MD ...                Brown
# 3     Applied Behavioral Rehabilitation Institute, I...
# 4     Arizona Opportunities Industrialization Center...              Gallego
# ...                                                 ...                  ...
# 1533  Western New Mexico University, NM, for an outd...
# 1534  William Jewell College, MO, for technology upg...
# 1535  Worcester State University, Worcester, MA for ...             McGovern
# 1536  York College, CUNY, Jamaica, NY for health dis...                Meeks
# 1537  Yuma Multiversity Campus Corporation, AZ, to d...
#
#       Requesters: Senate     Amount Origination
# 0                Schumer  1,000,000           H
# 1                  Smith    350,000           S
# 2                           500,000           H
# 3     Blumenthal, Murphy     25,000           S
# 4                         1,200,000           H
# ...                  ...        ...         ...
# 1533   Heinrich, Luja´ n    343,000           S
# 1534               Blunt  5,000,000           S
# 1535                      1,000,000           H
# 1536                      2,000,000           H
# 1537       Kelly, Sinema  1,519,000           S
#
# [1538 rows x 7 columns]
#           Agency       State                               Location  \
# 0           Army     Alabama                    Anniston Army Depot
# 1           Army      Alaska                        Fort Wainwright
# 2           Navy     Arizona                              MCAS Yuma
# 3           Navy  California                      NB Ventura County
# 4           Navy  California                            NB Coronado
# ..           ...         ...                                    ...
# 67       Army NG     Vermont                        Ethan Allen AFB
# 68       Army NG    Virginia                               Sandston
# 69        Air NG  Washington                       Camp Murray ANGS
# 70        Air NG   Wisconsin  Volk Combat Readiness Training Center
# 71  Army Reserve   Wisconsin                             Fort McCoy
#
#                                               Project      Amount  \
# 0                                    Welding Facility  25,010,000
# 1   ERDC–CRREL Permafrost Tunnel Research Facility...   5,400,000
# 2                        Combat Training Tank Complex  29,300,000
# 3                 Combat Vehicle Maintenance Facility  48,700,000
# 4                 CMV–22B Aircraft Maintenance Hangar  63,600,000
# ..                                                ...         ...
# 67  Family Readiness Center: Unspecified Minor Con...   4,665,000
# 68   Aircraft Maintenance Hangar: Planning and Design   5,805,000
# 69               Air Support Operations Group Complex  27,000,000
# 70  Replace Aircraft Maintenance Hangar/Shops: Pla...   2,280,000
# 71               Transient Training Enlisted Barracks  29,200,000
#
#    Requesters: House Requesters: Senate Origination
# 0        Rogers (AL)                              H
# 1                             Murkowski           S
# 2                         Kelly, Sinema           S
# 3                             Feinstein           S
# 4                             Feinstein           S
# ..               ...                ...         ...
# 67                       Leahy, Sanders           S
# 68                               Warner           S
# 69                               Murray           S
# 70                              Baldwin           S
# 71                              Baldwin           S
#
# [72 rows x 8 columns]
# failure cleaning Transportation, and Housing and Urban Development, and Related Agencies
#                                            Agency  \
# 0                    Department of Transportation
# 1                    Department of Transportation
# 2                    Department of Transportation
# 3                    Department of Transportation
# 4                    Department of Transportation
# ...                                           ...
# 1487  Department of Housing and Urban Development
# 1488  Department of Housing and Urban Development
# 1489  Department of Housing and Urban Development
# 1490  Department of Housing and Urban Development
# 1491  Department of Housing and Urban Development
#
#                                                 Account  \
# 0     Transportation Planning, Research, and Develop...
# 1     Transportation Planning, Research, and Develop...
# 2     Transportation Planning, Research, and Develop...
# 3     Transportation Planning, Research, and Develop...
# 4     Transportation Planning, Research, and Develop...
# ...                                                 ...
# 1487                         Community Development Fund
# 1488                         Community Development Fund
# 1489                         Community Development Fund
# 1490                         Community Development Fund
# 1491                         Community Development Fund
#
#                                                 Project  \
# 0                                EV ferry pilot program
# 1                West Santa Ana Branch Transit Corridor
# 2                     America’s Volunteer Driver Center
# 3     Sayreville Waterfront Multimodal Transportatio...
# 4     Study to Reestablish Passenger Rail Between Re...
# ...                                                 ...
# 1487  Shepherd University East Loop: Environmental R...
# 1488              Mountaineer Recovery Village— Phase 1
# 1489                             Crites Industrial Park
# 1490                      Mount Hope Facilities upgrade
# 1491                   Smithers Integrated Trail System
#
#                                               Recipient State      Amount  \
# 0                                 Southeast  Conference    AK  $2,000,000
# 1     Los  Angeles  County  Metropolitan \nTransport...    CA   1,000,000
# 2                                            ITNAmerica    ME   1,000,000
# 3     Sayreville  Economic  and  Rede-\nvelopment  A...    NJ   1,316,000
# 4                                         Berks  County    PA     750,000
# ...                                                 ...   ...         ...
# 1487                               Shepherd  University    WV   1,475,000
# 1488                                     Semper  Liberi    WV   1,500,000
# 1489      Hardy  County  Rural  Development \nAuthority    WV   2,268,000
# 1490                              City  of  Mount  Hope    WV   2,393,000
# 1491                                 City  of  Smithers    WV   4,688,000
#
#        Requesters: House Requesters: Senate Origination Requestor(s)
# 0                                 Murkowski           S          NaN
# 1                                 Feinstein           S          NaN
# 2                                   Collins           S          NaN
# 3                                  Menendez           S          NaN
# 4     Houlahan, \nMeuser              Casey         H/S          NaN
# ...                  ...                ...         ...          ...
# 1487                                 Capito           S          NaN
# 1488                                 Capito           S          NaN
# 1489                      Capito, \nManchin           S          NaN
# 1490                                 Capito           S          NaN
# 1491        Miller  (WV)  Capito, \nManchin         H/S          NaN
#
# [1492 rows x 10 columns]

# %% [markdown]
# ## Clean Files and Join Individual Category CSV Files into One Dataframe

# %%
allcategories = pd.DataFrame()

for index,row in links.iterrows():
    if index == 0:
        res = pd.read_csv("C:\\Users\\rorey\\OneDrive - Bipartisan Policy Center\\Congress\\Earmarks Data\\"+str(row["Category"])+".csv")

        ## clean and resave files
        
        res.columns = [clean(c) for c in res.columns]
        for c in res.columns:
            res[c] = res[c].map(lambda x: clean(x))
            
        try:
            res.drop(["Unnamed: 0"],axis=1,inplace=True)
        except:
            continue

        res.to_csv("C:\\Users\\rorey\\OneDrive - Bipartisan Policy Center\\Congress\\Earmarks Data\\"+str(row["Category"])+".csv",index=False)

        ## rename columns for consistency
        
        res.rename(columns={"Project Name":"Project","Amount Provided":"Amount","Total Amount Provided":"Amount","Project Description":"Project","Project Recipient and Name":"Project"},inplace=True)

        if "Project Name; Recipient" in res.columns:
            res["Project"] = res["Project Name; Recipient"].dropna().map(lambda x: x[:x.find(";")])
            res["Recipient"] = res["Project Name; Recipient"].dropna().map(lambda x: x[x.find(";")+1:])
            res.drop(["Project Name; Recipient"], axis=1,inplace=True)
    
        res["Category"] = [row["Category"]]*len(res["Agency"])
        
        allcategories = res
        
    else: # use first category to create results ("res") dataframe upon which to append others
        res = pd.read_csv("C:\\Users\\rorey\\OneDrive - Bipartisan Policy Center\\Congress\\Earmarks Data\\"+str(row["Category"])+".csv")
       
        res.columns = [clean(c) for c in res.columns]
        for c in res.columns:
            res[c] = res[c].map(lambda x: clean(x))
        try:
            res.drop(["Unnamed: 0"],axis=1,inplace=True)
        except:
            continue

        res.to_csv("C:\\Users\\rorey\\OneDrive - Bipartisan Policy Center\\Congress\\Earmarks Data\\"+str(row["Category"])+".csv",index=False)
        
        res.rename(columns={"Project Name":"Project","Amount Provided":"Amount","Total Amount Provided":"Amount","Project Description":"Project","Project Recipient and Name":"Project"},inplace=True)

    
        if "Project Name; Recipient" in res.columns:
            res["Project"] = res["Project Name; Recipient"].dropna().map(lambda x: x[:x.find(";")])
            res["Recipient"] = res["Project Name; Recipient"].dropna().map(lambda x: x[x.find(";")+1:])
            res.drop(["Project Name; Recipient"], axis=1,inplace=True)
    
        res["Category"] = [row["Category"]]*len(res["Agency"])


        allcategories = pd.concat([allcategories, res], ignore_index=True, sort=False)

try:
    allcategories.drop(["Unnamed: 0"],axis=1,inplace=True)
except:
    continue
    
allcategories = allcategories[['Category','Agency','Account','Project', 'Recipient','Location','State','Budget Request','Additional Amount','Amount','Requestors: House','Requestors: Senate','Requestor(s)','Origination']]

allcategories
# Out:
#                                            Agency                     Account  \
# 0      Animal and Plant Health Inspection Service                   APHIS S&E
# 1      Animal and Plant Health Inspection Service                   APHIS S&E
# 2      Animal and Plant Health Inspection Service                   APHIS S&E
# 3      Animal and Plant Health Inspection Service                   APHIS S&E
# 4      Animal and Plant Health Inspection Service                   APHIS S&E
# ...                                           ...                         ...
# 4969  Department of Housing and Urban Development  Community Development Fund
# 4970  Department of Housing and Urban Development  Community Development Fund
# 4971  Department of Housing and Urban Development  Community Development Fund
# 4972  Department of Housing and Urban Development  Community Development Fund
# 4973  Department of Housing and Urban Development  Community Development Fund
#
#                                                 Project  \
# 0                                Statewide Pest Surveys
# 1                                Feral Swine Management
# 2                         Invasive Species Surveillance
# 3                             Kula Agricultural Fencing
# 4                     O’Hare Federal Inspection Station
# ...                                                 ...
# 4969  Shepherd University East Loop: Environmental R...
# 4970              Mountaineer Recovery Village— Phase 1
# 4971                             Crites Industrial Park
# 4972                      Mount Hope Facilities upgrade
# 4973                   Smithers Integrated Trail System
#
#                                             Recipient Location     Amount  \
# 0                      Alaska Division of Agriculture       AK    100,000
# 1                  Arkansas Department of Agriculture       AR    650,000
# 2     Hawaii Department of Land and Natural Resources       HI    600,000
# 3                 Maui Office of Economic Development       HI    600,000
# 4                                     City of Chicago       IL    250,000
# ...                                               ...      ...        ...
# 4969                              Shepherd University      NaN  1,475,000
# 4970                                    Semper Liberi      NaN  1,500,000
# 4971         Hardy County Rural Development Authority      NaN  2,268,000
# 4972                               City of Mount Hope      NaN  2,393,000
# 4973                                 City of Smithers      NaN  4,688,000
#
#      Requesters: House Requesters: Senate Origination  \
# 0                  NaN          Murkowski           S
# 1                  NaN            Boozman           S
# 2                  NaN     Hirono; Schatz           S
# 3                  NaN             Schatz           S
# 4                  NaN             Durbin           S
# ...                ...                ...         ...
# 4969               NaN             Capito           S
# 4970               NaN             Capito           S
# 4971               NaN    Capito, Manchin           S
# 4972               NaN             Capito           S
# 4973       Miller (WV)    Capito, Manchin         H/S
#
#                                                Category Requestor(s)  \
# 0     Agriculture, Rural Development, Food and Drug ...          NaN
# 1     Agriculture, Rural Development, Food and Drug ...          NaN
# 2     Agriculture, Rural Development, Food and Drug ...          NaN
# 3     Agriculture, Rural Development, Food and Drug ...          NaN
# 4     Agriculture, Rural Development, Food and Drug ...          NaN
# ...                                                 ...          ...
# 4969  Transportation, and Housing and Urban Developm...          NaN
# 4970  Transportation, and Housing and Urban Developm...          NaN
# 4971  Transportation, and Housing and Urban Developm...          NaN
# 4972  Transportation, and Housing and Urban Developm...          NaN
# 4973  Transportation, and Housing and Urban Developm...          NaN
#
#      Budget Request Additional Amount State
# 0               NaN               NaN   NaN
# 1               NaN               NaN   NaN
# 2               NaN               NaN   NaN
# 3               NaN               NaN   NaN
# 4               NaN               NaN   NaN
# ...             ...               ...   ...
# 4969            NaN               NaN    WV
# 4970            NaN               NaN    WV
# 4971            NaN               NaN    WV
# 4972            NaN               NaN    WV
# 4973            NaN               NaN    WV
#
# [4974 rows x 14 columns]

# %%
allcategories.to_excel("C:\\Users\\rorey\\OneDrive - Bipartisan Policy Center\\Congress\\Earmarks Data\\AllFullyFundedCDSProjects.xlsx",index=False)
